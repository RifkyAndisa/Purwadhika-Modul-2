# %% [markdown]
# # Data Visualization
#
# # ``Line Plot & Scatter Plot``
#
#
# <hr>
#
# # __1. Line Plot / Line Chart__
#
# __Wikipedia__
#
# *A line chart or line plot or line graph or curve chart is a type of chart which displays information as a series of data points called 'markers' connected by straight line segments. It is a basic type of chart common in many fields. It is similar to a scatter plot except that the measurement points are ordered (typically by their x-axis value) and joined with straight line segments. A line chart is often used to visualize a trend in data over intervals of time – a time series – thus the line is often drawn chronologically. In these cases they are known as run charts.*
#
# ``A line chart is, as one can imagine, a line or multiple lines showing how single, or multiple variables develop over time. It is a great tool because we can easily highlight the magnitude of change of one or more variables over a period.``
#
# <img src='https://365datascience.com/wp-content/uploads/2018/07/12-Simple-line-chart.png' width=500 height=400/>
#
# ## __When to use line charts__
# A simple line chart would have been much better in that case. A line chart allows us to track the development of several variables at the same time. It is very easy to understand, and the reader doesn’t feel overwhelmed.
#
# ### Time Series by line plot
# Time series is a line plot and it is basically connecting data points with a straight line. It is useful in understanding the trend over time. It can explain the correlation between points by the trend. An upward trend means positive correlation and downward trend means a negative correlation. It mostly used in forecasting, monitoring models.
#
# __When to use__: Time Series should be used when single or multiple variables are to be plotted over time.
#
# eg: Stock Market Analysis of Companies, Weather Forecasting.
#
# <img src='https://miro.medium.com/max/1400/1*aYgw-zGwdRn_RE3h5KcIHQ.png' width=500 height=500/>

# %% [markdown]
# <hr>
#
# # __2. Scatter Plot__
#
# A scatter plot is a type of chart that is often used in the fields of statistics and data science. It consists of multiple data points plotted across two axes. Each variable depicted in a scatter plot would have multiple observations. If a scatter plot includes more than two variables, then we would use different colours to signify that.
#
# Scatter plot helps in visualizing 2 numeric variables. It helps in identifying the relationship of the data with each variable i.e correlation or trend patterns. It also helps in detecting outliers in the plot.
#
# __When to use__: ``A scatter plot chart is a great indicator that allows us to see whether there is a pattern to be found between two variables.``
#
# It is used in Machine learning concepts like regression, where x and y are continuous variables. It is also used in clustering scatters or outlier detection.
#
# <img src='https://365datascience.com/wp-content/uploads/2018/07/25-Scatter-plot-with-correlation-2.png' widht=500 height=500\>
#
# <img src='https://365datascience.com/wp-content/uploads/2018/07/26-scatter-plot-no-relationship-2.png' widht=500 height=500\>
#
# *So, this can be a very useful chart type whenever we would like to see if there is any relationship between two sets of data.*
#
#
# ``plt.scatter()`` takes 2 numeric arguments for scattering data points in the plot. It is similar to line plot except without the connected straight lines. By corr we mean correlation
#
# ### __When to avoid scatter plots__
#
# We can’t use scatter plots when we don’t have bi-dimensional data. In our example, we need information about both house prices and house size to create a scatter plot. A scatter plot requires at least two dimensions for our data.
#
# In addition, scatter plots are not suitable if we are interested in observing time patterns.
#
# Finally, a scatter plot is used with numerical data, or numbers. If we have categories such as 3 divisions, 5 products, and so on, a scatter plot would not reveal much.

# %% [markdown]
# # ``How to Create Lineplot, Stackedplot, & Scatterplot?``
#
# ### Anatomy of a figure
#
# <img src='https://miro.medium.com/max/1198/1*G3GHcehkrWy8xVRlvQRUQg.png' width=500 height=500/>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cleo = pd.read_csv('CLEO_JK.csv')
icbp = pd.read_csv('ICBP_JK.csv')
myor = pd.read_csv('MYOR_JK.csv')
tlkm = pd.read_csv('TLKM_JK.csv')

# %%
cleo.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2019-11-25  525.0  525.0  515.0  525.0      525.0   8169400
# 1  2019-11-26  525.0  530.0  520.0  525.0      525.0   6262100
# 2  2019-11-27  525.0  525.0  515.0  520.0      520.0   7498300
# 3  2019-11-28  520.0  520.0  505.0  510.0      510.0  10126600
# 4  2019-11-29  510.0  515.0  500.0  510.0      510.0   7746300

# %%
cleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       242 non-null    object
#  1   Open       242 non-null    float64
#  2   High       242 non-null    float64
#  3   Low        242 non-null    float64
#  4   Close      242 non-null    float64
#  5   Adj Close  242 non-null    float64
#  6   Volume     242 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.4+ KB

# %%
cleo['Date'] = pd.to_datetime(cleo['Date'])
cleo['Date']
# Out:
# 0     2019-11-25
# 1     2019-11-26
# 2     2019-11-27
# 3     2019-11-28
# 4     2019-11-29
#          ...
# 237   2020-11-17
# 238   2020-11-18
# 239   2020-11-19
# 240   2020-11-20
# 241   2020-11-23
# Name: Date, Length: 242, dtype: datetime64[ns]

# %%
icbp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       242 non-null    object
#  1   Open       242 non-null    float64
#  2   High       242 non-null    float64
#  3   Low        242 non-null    float64
#  4   Close      242 non-null    float64
#  5   Adj Close  242 non-null    float64
#  6   Volume     242 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.4+ KB

# %%
icbp['Date'] = pd.to_datetime(icbp['Date'])
tlkm['Date'] = pd.to_datetime(tlkm['Date'])
myor['Date'] = pd.to_datetime(myor['Date'])

# %% [markdown]
# ### __Matplotlib__

# %%
plt.figure(figsize=(10,6))
x = cleo['Date']
y = cleo['Close']
plt.plot(x, y, 'red')
plt.title('Harga Penutupan CLEO dari Bulan November 2019 - November 2020', size=20)
plt.xlabel('Daily')
plt.ylabel('Harga Saham per Lembar (IDR)')
plt.grid()
plt.show()

# %% [markdown]
# ## MYOR vs TLKM

# %%
myor.head()
# Out:
#         Date    Open    High     Low   Close    Adj Close   Volume
# 0 2019-11-25  2130.0  2150.0  2120.0  2120.0  2091.733398  1158300
# 1 2019-11-26  2120.0  2150.0  2070.0  2100.0  2072.000000  4942300
# 2 2019-11-27  2100.0  2110.0  2060.0  2100.0  2072.000000  2609000
# 3 2019-11-28  2100.0  2110.0  2060.0  2090.0  2062.133301  1443000
# 4 2019-11-29  2090.0  2090.0  2030.0  2060.0  2032.533325  1892600

# %%
tlkm.head()
# Out:
#         Date    Open    High     Low   Close    Adj Close     Volume
# 0 2019-11-25  4070.0  4070.0  3940.0  3950.0  3758.626221  107581200
# 1 2019-11-26  3950.0  3960.0  3860.0  3860.0  3672.986816  281002600
# 2 2019-11-27  3870.0  3930.0  3800.0  3880.0  3692.017822   97511300
# 3 2019-11-28  3830.0  3900.0  3800.0  3820.0  3634.924561   70635000
# 4 2019-11-29  3860.0  3950.0  3840.0  3930.0  3739.595215   72146900

# %%
len(tlkm)
# Out:
# 242

# %%
plt.figure(figsize=(20,10))

x = tlkm['Date']

plt.plot(x, tlkm['Close'], label='TLKM')
plt.plot(x, myor['Close'], label='MYOR')
# plt.plot(x, cleo['Close'], label='CLEO')
plt.title('Perbandingan Harga Penutupan TLKM vs MYOR')
plt.xlabel('Daily')
plt.ylabel('Harga Saham per Lembar (IDR)')
plt.legend()
plt.grid()
plt.show()

# %%
x
# Out:
# 0     2019-11-25
# 1     2019-11-26
# 2     2019-11-27
# 3     2019-11-28
# 4     2019-11-29
#          ...
# 237   2020-11-17
# 238   2020-11-18
# 239   2020-11-19
# 240   2020-11-20
# 241   2020-11-23
# Name: Date, Length: 242, dtype: datetime64[ns]

# %%
plt.figure(figsize=(10,7))

plt.subplot(2,2,1)
plt.title('TLKM')
plt.plot(x, tlkm['Close'], color='red')
plt.grid()

plt.subplot(2,2,2)
plt.title('ICBP')
plt.plot(x, icbp['Close'], color='blue')

plt.subplot(2,2,3)
plt.title('MYOR')
plt.plot(x, myor['Close'], color='green')

plt.subplot(2,2,4)
plt.title('CLEO')
plt.plot(x, cleo['Close'], color='yellow')
plt.grid()

plt.show()

# %%
fig, ax = plt.subplots(2,2)
fig.set_size_inches(16,16)
fig.suptitle('Perbandingan Harga Close Saham')
ax[0,0].plot(x, tlkm['Close'])
ax[0,0].set_title('TLKM')
ax[0,0].grid()

ax[1,1].plot(x, cleo['Close'])
ax[1,1].set_title('CLEO')

ax[1,0].plot(x, myor['Close'])
ax[1,0].set_title('MYOR')

ax[0,1].plot(x, icbp['Close'])
ax[0,1].set_title('ICBP')

plt.show()

# %%
fig, ax = plt.subplots(4,1, sharex=True)
fig.set_size_inches(8,16)
fig.suptitle('Perbandingan Harga Close Saham')
ax[0].plot(tlkm['Date'],tlkm['Close'], color='red')
ax[0].set_title('TLKM')
ax[0].grid()

ax[1].plot(cleo['Date'], cleo['Close'], color='green')
ax[1].set_title('CLEO')
ax[1].grid()


ax[2].plot(myor['Date'], myor['Close'], color='cyan')
ax[2].set_title('MYOR')
ax[2].grid()

ax[3].plot(icbp['Date'], myor['Close'], color='magenta')
ax[3].set_title('ICBP')
ax[3].grid()

plt.show()

# %%
icbp[icbp['Close']==icbp['Close'].min()]
# Out:
#           Date    Open    High     Low   Close    Adj Close    Volume
# 123 2020-05-29  8350.0  8500.0  8150.0  8150.0  7963.590332  61130900

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10,10)
fig.suptitle('Perbandingan Cleo & ICBP', color='white', size=20)

ax.set_title('Halo', color ='white', size=20)
ax.set_xlabel ('Tangal Harian', color='white', size=20)
ax.tick_params('x', colors='white')

'''
ax.set_ylim (bottom = 0, top = 1200) #Buat nge set range angkanya berapa
ax.set_xlim (bottom = 0, top = 1200)

'''


ax.plot(cleo['Date'], cleo['Close'],color='cyan', label='Cleo')
ax.set_ylabel('Stock Price CLEO', color='cyan', size=20)
ax.tick_params('y', colors='cyan', labelsize=15)
ax.grid()

ax2 = ax.twinx()
ax2.plot(icbp['Date'], icbp['Close'],color='red', label='Date', linestyle='--')
ax2.set_ylabel('Stock Price ICBP', color='red', size=20)
ax2.tick_params('y', colors='red', labelsize = 15)


ax2.annotate('Harga Terendah', xytext=(pd.Timestamp('2020-07-01'), 8100), #xytext untuk meletakan posisi si textnya ada di koordinat mana
             xy=(pd.Timestamp('2020-05-29'), icbp['Close'].min()), #xy koordinat dari data yang ingin kita cari (contoh di sini, data terendah dari setahun terakhir)
            arrowprops={'arrowstyle':'->', 'color':'b'}) #untuk membuat panah. yang menunjukan text yang kita buat dengan data yang kita cari
ax2.annotate('Harga Tertinggi', xytext=(pd.Timestamp('2020-03-01'), 11800),
             xy=(icbp[icbp['Close'] == icbp['Close'].max()]['Date'], icbp['Close'].max()),
            arrowprops={'arrowstyle':'->', 'color': 'blue'})



fig.legend()
plt.show()

# %% [markdown]
# ## __Seaborn (Lineplot)__
# - __AxesSubplot__ : is generated by plotting graph using seaborn library prefix. seaborn.scaterrplot or seaborn.countplot are two examples from this type of plot. We can just generate one plot graph using this type plot at one time. So if we want to create an array of graph or merely single graph we can use facetgrid type.
#
# - __FacetGrid__ : is an array of graph that has three dimensions, which are column, row and hue. It is easy and flexible to create subplot using row and column variable. Seaborn catplot or seaborn relplot are samples of facet grid type. Relplot is usually used to plot scattered plot or line plot to create relation between to variable. We can choose type of graph line or scatter by define it at kind variable in relplot command. We can define dimension for column by using col variable and col_wrap to define how many column will be generated.

# %%
plt.figure()
a = sns.relplot(data=cleo, x='Date', y='Close', kind='line', color='red')
b = sns.relplot(data=icbp, x='Date', y='Close', kind='line', color='cyan')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
c = sns.lineplot(data=icbp, x='Date', y='Close', color='blue')
c.set_xticklabels(icbp['Date'], rotation=90)

plt.subplot(122)
d = sns.lineplot(data=myor, x='Date', y='Close', color='red')
d.set_xticklabels(myor['Date'], rotation=90)

plt.show()
# Out:
# <ipython-input-20-f4c51795c702>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   c.set_xticklabels(icbp['Date'], rotation=90)
# <ipython-input-20-f4c51795c702>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   d.set_xticklabels(myor['Date'], rotation=90)

# %%
icbp
# Out:
#           Date     Open     High      Low    Close     Adj Close    Volume
# 0   2019-11-25  11375.0  11425.0  11375.0  11400.0  11139.255859   8105000
# 1   2019-11-26  11375.0  11425.0  11375.0  11375.0  11114.827148  13063100
# 2   2019-11-27  11325.0  11550.0  11300.0  11375.0  11114.827148   2689000
# 3   2019-11-28  11450.0  11525.0  11325.0  11325.0  11065.970703   2859600
# 4   2019-11-29  11325.0  11500.0  11300.0  11325.0  11065.970703   3762100
# ..         ...      ...      ...      ...      ...           ...       ...
# 237 2020-11-17   9800.0  10475.0   9800.0  10250.0  10250.000000  24735800
# 238 2020-11-18  10250.0  10475.0  10250.0  10275.0  10275.000000  10675000
# 239 2020-11-19  10275.0  10400.0  10150.0  10350.0  10350.000000   7159300
# 240 2020-11-20  10400.0  10400.0  10100.0  10100.0  10100.000000  10424600
# 241 2020-11-23  10150.0  10225.0  10125.0  10200.0  10200.000000   2206900
#
# [242 rows x 7 columns]

# %%
c = sns.lineplot(data=icbp, x='Date', y='Close', color='blue')
d = sns.lineplot(data=myor, x='Date', y='Close', color='red')
plt.show()

# %% [markdown]
# ## __Matplotlib (Scatter)__

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
i = 4
plt.plot(tips['tip'], tips['total_bill'], linestyle='None', marker='o')
plt.plot(tips['tip'][i], tips['total_bill'][i], linestyle='None', marker='o', color='red')
plt.show()

# %%
tips[tips['tip'] == tips['tip'].max()]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
plt.scatter(tips['tip'], tips['total_bill'])
plt.scatter(tips['tip'][i], tips['total_bill'][i], color='red')
plt.ylabel('Total Bill')
plt.xlabel('Tip')
plt.show()

# %%
male = tips[tips['sex']=='Male']
female = tips[tips['sex']=='Female']

# %%
male.head()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        8.77  2.00  Male     No  Sun  Dinner     2

# %%
female.head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
plt.scatter(male['tip'], male['total_bill'], label='Male')
plt.scatter(female['tip'], female['total_bill'], label='Female')
plt.xlabel('TIPS')
plt.ylabel('Total Bill')
plt.legend()
plt.show()

# %% [markdown]
# ## __SEABORN (scatter)__

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill')
plt.show()

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='sex', hue_order=['Male','Female'])
plt.show()

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='sex',
                hue_order=['Male','Female'], style='smoker')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='sex',
                hue_order=['Male','Female'], style='smoker', size='tip')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='sex',
                hue_order=['Male','Female'], style='smoker', size='tip',
               palette={'Male':'green', 'Female':'purple'})
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='sex',
                hue_order=['Male','Female'], style='smoker', size='tip',
               palette={'Male':'green', 'Female':'purple'}, alpha=0.4)
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=tips)
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='smoker')
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=tips, row='smoker')
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=tips, row='smoker', col='sex')
plt.show()

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='day')
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='day', col_wrap=2)
sns.relplot(x='tip', y='total_bill', data=tips, col='day')
plt.show()

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='day', col_wrap=2, hue='sex',
            col_order=['Sun','Sat','Fri','Thur'])
plt.show()

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights['year'].value_counts()
# Out:
# 1960    12
# 1959    12
# 1958    12
# 1957    12
# 1956    12
# 1955    12
# 1954    12
# 1953    12
# 1952    12
# 1951    12
# 1950    12
# 1949    12
# Name: year, dtype: int64

# %%
sns.relplot(data=flights, x='year', y='passengers', hue='month', kind='line')
plt.show()

# %%
#boots traping / sampling ulang bisa pakau ini/ CI= Confidential Index
sns.relplot(x='year', y='passengers', kind='line', data=flights)
#di tabel 1 garis biru di tengah itu meannya, sedangkan biru yang ada di atas dan bawahnya
#kemungkinan lain dari mean tertinggi dan terendah, setelah di lakukan bootstraping berulang kali
sns.relplot(x='year', y='passengers', kind='line', data=flights, ci=None)
plt.show()

# %%
flights[flights['year']==1950]
# Out:
#     year month  passengers
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170
# 20  1950   Sep         158
# 21  1950   Oct         133
# 22  1950   Nov         114
# 23  1950   Dec         140

# %%
flights[flights['year']==1950]['passengers'].mean()
# Out:
# 139.66666666666666

# %% [markdown]
# ## __3.Stack Plot__

# %%
days =[1,2,3,4,5]

sleeping = [7,4,5,6,3]
eating = [3,4,5,6,3]
working = [8,8,8,8,8]
playing = [7,8,6,4,10]

plt.stackplot(days, [sleeping,eating,working,playing], labels=('sleeping', 'eating','working','playing'))
plt.xlabel('Days')
plt.ylabel('Hour Activity')
plt.ylim(0,24)
plt.legend()
plt.show()

# %%
sleeping_perc = pd.Series(sleeping).divide(24)
eating_perc = pd.Series(eating).divide(24)
working_perc = pd.Series(working).divide(24)
playing_perc = pd.Series(playing).divide(24)

# %%
activity = np.vstack([sleeping_perc,eating_perc,working_perc,playing_perc])
plt.stackplot(days, activity, labels=('sleeping', 'eating','working','playing'))
plt.xlabel('Days')
plt.ylabel('Hour Activity')
plt.legend()
plt.show()

# %%
activity
# Out:
# array([[0.29166667, 0.16666667, 0.20833333, 0.25      , 0.125     ],
#        [0.125     , 0.16666667, 0.20833333, 0.25      , 0.125     ],
#        [0.33333333, 0.33333333, 0.33333333, 0.33333333, 0.33333333],
#        [0.29166667, 0.33333333, 0.25      , 0.16666667, 0.41666667]])

# %%
volume = np.vstack([cleo['Volume'], myor['Volume'],icbp['Volume'],tlkm['Volume']])
vol_df = pd.DataFrame(volume, index=['CLEO','MYOR','ICBP','TLKM'], columns=cleo['Date'])
vol_df = vol_df.T
vol_df
# Out:
#                 CLEO      MYOR      ICBP       TLKM
# Date
# 2019-11-25   8169400   1158300   8105000  107581200
# 2019-11-26   6262100   4942300  13063100  281002600
# 2019-11-27   7498300   2609000   2689000   97511300
# 2019-11-28  10126600   1443000   2859600   70635000
# 2019-11-29   7746300   1892600   3762100   72146900
# ...              ...       ...       ...        ...
# 2020-11-17   8873000   2827700  24735800  527501800
# 2020-11-18  12405800  12736200  10675000  239122600
# 2020-11-19  19700400   5912600   7159300  185558800
# 2020-11-20  12207300   5353400  10424600  211892500
# 2020-11-23   5992300   1151300   2206900  140739900
#
# [242 rows x 4 columns]

# %%
vol_df['Total'] = vol_df[['CLEO','MYOR','ICBP','TLKM']].sum(axis=1)
vol_df_perc = vol_df.copy()
vol_df
# Out:
#                 CLEO      MYOR      ICBP       TLKM      Total
# Date
# 2019-11-25   8169400   1158300   8105000  107581200  125013900
# 2019-11-26   6262100   4942300  13063100  281002600  305270100
# 2019-11-27   7498300   2609000   2689000   97511300  110307600
# 2019-11-28  10126600   1443000   2859600   70635000   85064200
# 2019-11-29   7746300   1892600   3762100   72146900   85547900
# ...              ...       ...       ...        ...        ...
# 2020-11-17   8873000   2827700  24735800  527501800  563938300
# 2020-11-18  12405800  12736200  10675000  239122600  274939600
# 2020-11-19  19700400   5912600   7159300  185558800  218331100
# 2020-11-20  12207300   5353400  10424600  211892500  239877800
# 2020-11-23   5992300   1151300   2206900  140739900  150090400
#
# [242 rows x 5 columns]

# %%
vol_df_perc['CLEO'] =vol_df['CLEO']/vol_df['Total']*100
vol_df_perc['MYOR'] =vol_df['MYOR']/vol_df['Total']*100
vol_df_perc['ICBP'] =vol_df['ICBP']/vol_df['Total']*100
vol_df_perc['TLKM'] =vol_df['TLKM']/vol_df['Total']*100
vol_df_perc['Total'] = vol_df_perc['CLEO MYOR ICBP TLKM'.split()].sum(axis=1)
vol_df_perc
#membuat totalnya jadi 100%
# Out:
#                  CLEO      MYOR      ICBP       TLKM  Total
# Date
# 2019-11-25   6.534793  0.926537  6.483279  86.055391  100.0
# 2019-11-26   2.051331  1.618992  4.279194  92.050483  100.0
# 2019-11-27   6.797628  2.365204  2.437729  88.399439  100.0
# 2019-11-28  11.904656  1.696366  3.361696  83.037282  100.0
# 2019-11-29   9.054927  2.212328  4.397653  84.335092  100.0
# ...               ...       ...       ...        ...    ...
# 2020-11-17   1.573399  0.501420  4.386260  93.538921  100.0
# 2020-11-18   4.512191  4.632363  3.882671  86.972775  100.0
# 2020-11-19   9.023176  2.708089  3.279102  84.989633  100.0
# 2020-11-20   5.088966  2.231720  4.345796  88.333518  100.0
# 2020-11-23   3.992461  0.767071  1.470381  93.770088  100.0
#
# [242 rows x 5 columns]

# %%
vol_df_perc_t = vol_df_perc.T
vol_df_ready = vol_df_perc_t.iloc[0:4, :]
vol_df_ready
# Out:
# Date  2019-11-25  2019-11-26  2019-11-27  2019-11-28  2019-11-29  2019-12-02  \
# CLEO    6.534793    2.051331    6.797628   11.904656    9.054927    7.792756
# MYOR    0.926537    1.618992    2.365204    1.696366    2.212328    0.993064
# ICBP    6.483279    4.279194    2.437729    3.361696    4.397653    3.166874
# TLKM   86.055391   92.050483   88.399439   83.037282   84.335092   88.047306
#
# Date  2019-12-03  2019-12-04  2019-12-05  2019-12-06  ...  2020-11-10  \
# CLEO    9.234004    9.332024    5.989930   12.812221  ...    3.612372
# MYOR    1.341804    3.386762    1.244089    3.180843  ...    1.834515
# ICBP    2.791878    7.880276    4.739452    3.308224  ...    9.288726
# TLKM   86.632313   79.400938   88.026529   80.698712  ...   85.264387
#
# Date  2020-11-11  2020-11-12  2020-11-13  2020-11-16  2020-11-17  2020-11-18  \
# CLEO    1.523149    2.588326    2.888550    2.792983    1.573399    4.512191
# ...

# %%
vol_df_perc['TLKM'].mean()
# Out:
# 84.78612622413651

# %%
# vol_df_ready.values.shape # values = hanya menampilkan arraynya saja, shapenya bisa di hapus

# %%
plt.figure(figsize=(16,10))
plt.stackplot(vol_df_ready.columns, vol_df_ready, labels=vol_df_ready.index,
             colors=['blue','yellow','green','cyan'])
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 10))
plt.stackplot(vol_df_ready.columns, vol_df_ready, labels=vol_df_ready.index,
             colors=['red','green','cyan','blue'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
